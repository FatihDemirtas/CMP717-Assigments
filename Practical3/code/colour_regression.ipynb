# %% [markdown]
# # Colab FAQ
#
# For some basic overview and features offered in Colab notebooks, check out: [Overview of Colaboratory Features](https://colab.research.google.com/notebooks/basic_features_overview.ipynb)
#
# You need to use the colab GPU for this assignmentby selecting:
#
# > **Runtime**   →   **Change runtime type**   →   **Hardware Accelerator: GPU**

# %% [markdown]
# # Download CIFAR and Colour dictionary
# It can take up to a couple of minutes to download everything the first time.
#
# All files are stored at /content/cmp717/pa3/data/ folder

# %% [markdown]
# ## Helper code
# You can ignore the restart warning.

# %%
######################################################################
# Setup python environment and change the current working directory
######################################################################
# !pip install torch torchvision
# !pip install Pillow==4.0.0
# %mkdir -p /content/cmp717/pa3/
# %cd /content/cmp717/pa3
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.7.0+cu101)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.8.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch) (0.16.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch) (3.7.4.3)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch) (0.8)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (7.0.0)
# Collecting Pillow==4.0.0
#   Downloading https://files.pythonhosted.org/packages/37/e8/b3fbf87b0188d22246678f8cd61e23e31caa1769ebc06f1664e2e5fe8a17/Pillow-4.0.0-cp36-cp36m-manylinux1_x86_64.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 12.2MB/s
# Collecting olefile
#   Downloading https://files.pythonhosted.org/packages/34/81/e1ac43c6b45b4c5f8d9352396a14144bba52c8fec72a80f425f6a4d653ad/olefile-0.46.zip (112kB)
#      |████████████████████████████████| 112kB 53.0MB/s
# Building wheels for collected packages: olefile
#   Building wheel for olefile (setup.py) ... done
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35415 sha256=ebcd94de229c44068b85c7c5d4e87be63e981103f131d8f41494b5ca3fe65b2f
#   Stored in directory: /root/.cache/pip/wheels/4b/f4/11/bc4166107c27f07fd7bba707ffcb439619197638a1ac986df3
# Successfully built olefile
# ERROR: torchvision 0.8.1+cu101 has requirement pillow>=4.1.1, but you'll have pillow 4.0.0 which is incompatible.
# ERROR: scikit-image 0.16.2 has requirement pillow>=4.3.0, but you'll have pillow 4.0.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: olefile, Pillow
#   Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
# Successfully installed Pillow-4.0.0 olefile-0.46
# /content/cmp717/pa3

# %%
# adapted from 
# https://github.com/fchollet/keras/blob/master/keras/datasets/cifar10.py

import os
from six.moves.urllib.request import urlretrieve
import tarfile
import numpy as np
import pickle
import sys

def get_file(fname,
             origin,
             untar=False,
             extract=False,
             archive_format='auto',
             cache_dir='data'):
    datadir = os.path.join(cache_dir)
    if not os.path.exists(datadir):
        os.makedirs(datadir)

    if untar:
        untar_fpath = os.path.join(datadir, fname)
        fpath = untar_fpath + '.tar.gz'
    else:
        fpath = os.path.join(datadir, fname)
    
    print(fpath)
    if not os.path.exists(fpath):
        print('Downloading data from', origin)

        error_msg = 'URL fetch failure on {}: {} -- {}'
        try:
            try:
                urlretrieve(origin, fpath)
            except URLError as e:
                raise Exception(error_msg.format(origin, e.errno, e.reason))
            except HTTPError as e:
                raise Exception(error_msg.format(origin, e.code, e.msg))
        except (Exception, KeyboardInterrupt) as e:
            if os.path.exists(fpath):
                os.remove(fpath)
            raise

    if untar:
        if not os.path.exists(untar_fpath):
            print('Extracting file.')
            with tarfile.open(fpath) as archive:
                archive.extractall(datadir)
        return untar_fpath

    if extract:
        _extract_archive(fpath, datadir, archive_format)

    return fpath



def load_batch(fpath, label_key='labels'):
    """Internal utility for parsing CIFAR data.
    # Arguments
        fpath: path the file to parse.
        label_key: key for label data in the retrieve
            dictionary.
    # Returns
        A tuple `(data, labels)`.
    """
    f = open(fpath, 'rb')
    if sys.version_info < (3,):
        d = pickle.load(f)
    else:
        d = pickle.load(f, encoding='bytes')
        # decode utf8
        d_decoded = {}
        for k, v in d.items():
            d_decoded[k.decode('utf8')] = v
        d = d_decoded
    f.close()
    data = d['data']
    labels = d[label_key]

    data = data.reshape(data.shape[0], 3, 32, 32)
    return data, labels

def load_cifar10(transpose=False):
    """Loads CIFAR10 dataset.
    # Returns
        Tuple of Numpy arrays: `(x_train, y_train), (x_test, y_test)`.
    """
    dirname = 'cifar-10-batches-py'
    origin = 'http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz'
    path = get_file(dirname, origin=origin, untar=True)

    num_train_samples = 50000

    x_train = np.zeros((num_train_samples, 3, 32, 32), dtype='uint8')
    y_train = np.zeros((num_train_samples,), dtype='uint8')

    for i in range(1, 6):
        fpath = os.path.join(path, 'data_batch_' + str(i))
        data, labels = load_batch(fpath)
        x_train[(i - 1) * 10000: i * 10000, :, :, :] = data
        y_train[(i - 1) * 10000: i * 10000] = labels

    fpath = os.path.join(path, 'test_batch')
    x_test, y_test = load_batch(fpath)

    y_train = np.reshape(y_train, (len(y_train), 1))
    y_test = np.reshape(y_test, (len(y_test), 1))

    if transpose:
        x_train = x_train.transpose(0, 2, 3, 1)
        x_test = x_test.transpose(0, 2, 3, 1)
    return (x_train, y_train), (x_test, y_test)

# %% [markdown]
# ## Download files
#
# This may take 1 or 2 mins for the first time.

# %%
######################################################################
# Download CIFAR datasets and other related files
######################################################################
colours_fpath = get_file(fname='colours', 
                         origin='http://www.cs.toronto.edu/~jba/kmeans_colour_a2.tar.gz', 
                         untar=True)
m = load_cifar10()
# Out:
# data/colours.tar.gz
# Downloading data from http://www.cs.toronto.edu/~jba/kmeans_colour_a2.tar.gz
# Extracting file.
# data/cifar-10-batches-py.tar.gz
# Downloading data from http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Extracting file.

# %% [markdown]
# # Code for training and CNN models

# %% [markdown]
# ## Data preprocessing

# %%
"""
Colourization of CIFAR-10 Horses via classification.
"""
from __future__ import print_function
import argparse
import math
import numpy as np
import numpy.random as npr
import scipy.misc
import time
import torch 
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib
import matplotlib.pyplot as plt 


#from load_data import load_cifar10

HORSE_CATEGORY = 7

######################################################################
# Data related code
######################################################################
def get_rgb_cat(xs, colours):
    """
    Get colour categories given RGB values. This function doesn't
    actually do the work, instead it splits the work into smaller
    chunks that can fit into memory, and calls helper function
    _get_rgb_cat

    Args:
      xs: float numpy array of RGB images in [B, C, H, W] format
      colours: numpy array of colour categories and their RGB values
    Returns:
      result: int numpy array of shape [B, 1, H, W]
    """
    if np.shape(xs)[0] < 100:
        return _get_rgb_cat(xs)
    batch_size = 100
    nexts = []
    for i in range(0, np.shape(xs)[0], batch_size):
        next = _get_rgb_cat(xs[i:i+batch_size,:,:,:], colours)
        nexts.append(next)
    result = np.concatenate(nexts, axis=0)
    return result

def _get_rgb_cat(xs, colours):
    """
    Get colour categories given RGB values. This is done by choosing
    the colour in `colours` that is the closest (in RGB space) to
    each point in the image `xs`. This function is a little memory
    intensive, and so the size of `xs` should not be too large.

    Args:
      xs: float numpy array of RGB images in [B, C, H, W] format
      colours: numpy array of colour categories and their RGB values
    Returns:
      result: int numpy array of shape [B, 1, H, W]
    """
    num_colours = np.shape(colours)[0]
    xs = np.expand_dims(xs, 0)
    cs = np.reshape(colours, [num_colours,1,3,1,1])
    dists = np.linalg.norm(xs-cs, axis=2) # 2 = colour axis
    cat = np.argmin(dists, axis=0)
    cat = np.expand_dims(cat, axis=1)
    return cat

def get_cat_rgb(cats, colours):
    """
    Get RGB colours given the colour categories

    Args:
      cats: integer numpy array of colour categories
      colours: numpy array of colour categories and their RGB values
    Returns:
      numpy tensor of RGB colours
    """
    return colours[cats]

def process(xs, ys, max_pixel=256.0, downsize_input=False):
    """
    Pre-process CIFAR10 images by taking only the horse category,
    shuffling, and have colour values be bound between 0 and 1

    Args:
      xs: the colour RGB pixel values
      ys: the category labels
      max_pixel: maximum pixel value in the original data
    Returns:
      xs: value normalized and shuffled colour images
      grey: greyscale images, also normalized so values are between 0 and 1
    """
    xs = xs / max_pixel
    xs = xs[np.where(ys == HORSE_CATEGORY)[0], :, :, :]
    npr.shuffle(xs)
    grey = np.mean(xs, axis=1, keepdims=True)
    if downsize_input:
      avg_pool = nn.Sequential(nn.AvgPool2d(2),nn.AvgPool2d(2), 
                               nn.Upsample(scale_factor=2, mode='bilinear'), nn.Upsample(scale_factor=2, mode='bilinear'))
      grey_downsized = avg_pool.forward(torch.from_numpy(grey).float())
      grey = grey_downsized.data.numpy()
    return (xs, grey)


def get_batch(x, y, batch_size):
    '''
    Generated that yields batches of data

    Args:
      x: input values
      y: output values
      batch_size: size of each batch
    Yields:
      batch_x: a batch of inputs of size at most batch_size
      batch_y: a batch of outputs of size at most batch_size
    '''
    N = np.shape(x)[0]
    assert N == np.shape(y)[0]
    for i in range(0, N, batch_size):
        batch_x = x[i:i+batch_size, :,:,:]
        batch_y = y[i:i+batch_size, :,:,:]
        yield (batch_x, batch_y)

######################################################################
# Torch Helper
######################################################################

def get_torch_vars(xs, ys, gpu=False):
    """
    Helper function to convert numpy arrays to pytorch tensors.
    If GPU is used, move the tensors to GPU.

    Args:
      xs (float numpy tenosor): greyscale input
      ys (int numpy tenosor): categorical labels 
      gpu (bool): whether to move pytorch tensor to GPU
    Returns:
      Variable(xs), Variable(ys)
    """
    xs = torch.from_numpy(xs).float()
    ys = torch.from_numpy(ys).float()
    if gpu:
        xs = xs.cuda()
        ys = ys.cuda()
    return Variable(xs), Variable(ys)

def compute_loss(criterion, outputs, labels, batch_size, num_colours):
    """
    Helper function to compute the loss. Since this is a pixelwise
    prediction task we need to reshape the output and ground truth
    tensors into a 2D tensor before passing it in to the loss criteron.

    Args:
      criterion: pytorch loss criterion
      outputs (pytorch tensor): predicted labels from the model
      labels (pytorch tensor): ground truth labels
      batch_size (int): batch size used for training
      num_colours (int): number of colour categories
    Returns:
      pytorch tensor for loss
    """

    loss_out = outputs.transpose(1,3) \
                      .contiguous() \
                      .view([batch_size*32*32, num_colours])
    loss_lab = labels.transpose(1,3) \
                      .contiguous() \
                      .view([batch_size*32*32])
    return criterion(loss_out, loss_lab)

def run_validation_step(cnn, criterion, test_grey, test_rgb_cat, batch_size,
                        colours, plotpath=None, visualize=True):
    correct = 0.0
    total = 0.0
    losses = []
    num_colours = np.shape(colours)[0]
    for i, (xs, ys) in enumerate(get_batch(test_grey,
                                           test_rgb_cat,
                                           batch_size)):
        images, labels = get_torch_vars(xs, ys, args.gpu)
        outputs = cnn(images)

        val_loss = compute_loss(criterion,
                                outputs,
                                labels,
                                batch_size=args.batch_size,
                                num_colours=num_colours)
        losses.append(val_loss.data.item())

        _, predicted = torch.max(outputs.data, 1, keepdim=True)
        total += labels.size(0) * 32 * 32
        correct += (predicted == labels.data).sum()

    if plotpath: # only plot if a path is provided
        plot(xs, ys, predicted.cpu().numpy(), colours, 
             plotpath, visualize=visualize)

    val_loss = np.mean(losses)
    val_acc = 100 * correct / total
    return val_loss, val_acc

# %% [markdown]
# ## Visualization

# %%
def plot(input, gtlabel, output, colours, path, visualize):
    """
    Generate png plots of input, ground truth, and outputs

    Args:
      input: the greyscale input to the colourization CNN
      gtlabel: the grouth truth categories for each pixel
      output: the predicted categories for each pixel
      colours: numpy array of colour categories and their RGB values
      path: output path
    """
    k = 10
    grey = np.transpose(input[:k,:,:,:], [0,2,3,1])
    if colours is None:
      gtcolor = np.transpose(gtlabel[:k,:,:,:], [0,2,3,1])
      predcolor = np.transpose(output[:k,:,:,:], [0,2,3,1])
    else:
      gtcolor = get_cat_rgb(gtlabel[:k,0,:,:], colours)
      predcolor = get_cat_rgb(output[:k,0,:,:], colours)

    img = np.vstack([
      np.hstack(np.tile(grey, [1,1,1,3])),
      np.hstack(gtcolor),
      np.hstack(predcolor)])
    #plt.figure()
    plt.grid('off')
    plt.imshow(img, vmin=0., vmax=1.)
    if visualize:
      plt.show()
    else:
      plt.savefig(path)

# %% [markdown]
# ## Training

# %%
class AttrDict(dict):
    def __init__(self, *args, **kwargs):
        super(AttrDict, self).__init__(*args, **kwargs)
        self.__dict__ = self

def train(args, cnn=None):
    # Set the maximum number of threads to prevent crash in Teaching Labs
    torch.set_num_threads(5)
    # Numpy random seed
    npr.seed(args.seed)
    
    # Save directory
    save_dir = "outputs/" + args.experiment_name

    # LOAD THE MODEL
    if cnn is None:
      cnn = RegressionCNN(args.kernel, args.num_filters)
      print(cnn)

      
    # Set up L2 loss
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(cnn.parameters(), lr=args.learn_rate)
    

    # Loading & transforming data
    print("Loading data...")    
    (x_train, y_train), (x_test, y_test) = load_cifar10()
    train_rgb, train_grey = process(x_train, y_train)
    test_rgb, test_grey = process(x_test, y_test)


    # Create the outputs folder if not created already
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    print("Beginning training ...")
    if args.gpu: cnn.cuda()
    start = time.time()

    trn_losses = []
    val_losses = []
    for epoch in range(args.epochs):
        # Train the Model
        cnn.train() # Change model to 'train' mode
        for i, (xs, ys) in enumerate(get_batch(train_grey,
                                               train_rgb,
                                               args.batch_size)):
            images, labels = get_torch_vars(xs, ys, args.gpu)
            # Forward + Backward + Optimize
            optimizer.zero_grad()
            outputs = cnn(images)

            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
        trn_losses.append(loss.data.item())   
        print('Epoch [%d/%d], Loss: %.4f' % (epoch+1, args.epochs, loss.data.item()))

        # Evaluate the model
        cnn.eval()  # Change model to 'eval' mode (BN uses moving mean/var).
        losses = []
        for i, (xs, ys) in enumerate(get_batch(test_grey,
                                               test_rgb,
                                               args.batch_size)):
            images, labels = get_torch_vars(xs, ys, args.gpu)
            outputs = cnn(images)

            val_loss = criterion(outputs, labels)
            losses.append(val_loss.data.item())

        val_loss = np.mean(losses)
        val_losses.append(val_loss)
        print('Epoch [%d/%d], Val Loss: %.4f' % (epoch+1, args.epochs, val_loss))
        

    # Plot training curve
    plt.figure()
    plt.plot(trn_losses, "ro-", label="Train")
    plt.plot(val_losses, "go-", label="Validation")
    plt.legend()
    plt.title("Loss")
    plt.xlabel("Epochs")

    plt.figure()
    print("Generating predictions...")
    plot(xs, ys, outputs.cpu().data, colours=None, 
             path=save_dir+"/regression_output.png", visualize=args.visualize)
#     grey = test_grey[:15]
#     gtrgb = test_rgb[:15]
#     grey, gtrgb = get_torch_vars(test_grey[:15], test_rgb[:15], args.gpu)
#     predrgb = cnn(grey)
#     plot(grey.cpu().data, gtrgb.cpu().data, predrgb.cpu().data, colours=None, 
#          path=save_dir+"/regression_output.png", visualize=args.visualize)

    if args.checkpoint:
        print('Saving model...')
        torch.save(cnn.state_dict(), args.checkpoint)
    
    return cnn

# %% [markdown]
# ## Regression network

# %%
class MyConv2d(nn.Module):
    """
    Our simplified implemented of nn.Conv2d module for 2D convolution
    """
    def __init__(self, in_channels, out_channels, kernel_size, padding=None):
        super(MyConv2d, self).__init__()

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size
        if padding is None:
            self.padding = kernel_size // 2
        else:
            self.padding = padding
        self.weight = nn.parameter.Parameter(torch.Tensor(
            out_channels, in_channels, kernel_size, kernel_size))
        self.bias = nn.parameter.Parameter(torch.Tensor(out_channels))
        self.reset_parameters()

    def reset_parameters(self):
        n = self.in_channels * self.kernel_size * self.kernel_size
        stdv = 1. / math.sqrt(n)
        self.weight.data.uniform_(-stdv, stdv)
        self.bias.data.uniform_(-stdv, stdv)

    def forward(self, input):
        return F.conv2d(input, self.weight, self.bias, padding=self.padding)


class RegressionCNN(nn.Module):
    def __init__(self, kernel, num_filters):
        # first call parent's initialization function
        super(RegressionCNN, self).__init__()
        padding = kernel // 2

        self.downconv1 = nn.Sequential(
            nn.Conv2d(1, num_filters, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(num_filters),
            nn.ReLU(),
            nn.MaxPool2d(2),)
        self.downconv2 = nn.Sequential(
            nn.Conv2d(num_filters, num_filters*2, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(num_filters*2),
            nn.ReLU(),
            nn.MaxPool2d(2),)

        self.rfconv = nn.Sequential(
            nn.Conv2d(num_filters*2, num_filters*2, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(num_filters*2),
            nn.ReLU())

        self.upconv1 = nn.Sequential(
            nn.Conv2d(num_filters*2, num_filters, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(num_filters),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),)
        self.upconv2 = nn.Sequential(
            nn.Conv2d(num_filters, 3, kernel_size=kernel, padding=padding),
            nn.BatchNorm2d(3),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),)
        self.finalconv = MyConv2d(3, 3, kernel_size=kernel)

    def forward(self, x):
        out = self.downconv1(x)
        out = self.downconv2(out)
        out = self.rfconv(out)
        out = self.upconv1(out)
        out = self.upconv2(out)
        out = self.finalconv(out)
        return out

# %% [markdown]
# # CIFAR-10 colour regression

# %% [markdown]
# ## Main training loop for regression CNN

# %%
args = AttrDict()
args_dict = {
              'gpu':True, 
              'valid':False, 
              'checkpoint':"", 
              'kernel':3,
              'num_filters':32, 
              'learn_rate':0.001, 
              'batch_size':100, 
              'epochs':10, 
              'seed':0,
              'plot':True, 
              'experiment_name': 'regression_cnn',
              'visualize': False,
              'downsize_input':False,
}
args.update(args_dict)
cnn = train(args)
# Out:
# RegressionCNN(
#   (downconv1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (downconv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (rfconv): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (upconv1): Sequential(
#     (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Upsample(scale_factor=2.0, mode=nearest)
#   )
#   (upconv2): Sequential(
#     (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Upsample(scale_factor=2.0, mode=nearest)
#   )
#   (finalconv): MyConv2d()
# )
# Loading data...
# data/cifar-10-batches-py.tar.gz
# Beginning training ...
# Epoch [1/10], Loss: 0.0363
# Epoch [1/10], Val Loss: 0.0378
# Epoch [2/10], Loss: 0.0182
# Epoch [2/10], Val Loss: 0.0179
# Epoch [3/10], Loss: 0.0158
# Epoch [3/10], Val Loss: 0.0155
# Epoch [4/10], Loss: 0.0145
# Epoch [4/10], Val Loss: 0.0145
# Epoch [5/10], Loss: 0.0137
# Epoch [5/10], Val Loss: 0.0134
# Epoch [6/10], Loss: 0.0130
# Epoch [6/10], Val Loss: 0.0127
# Epoch [7/10], Loss: 0.0122
# Epoch [7/10], Val Loss: 0.0123
# Epoch [8/10], Loss: 0.0116
# Epoch [8/10], Val Loss: 0.0118
# Epoch [9/10], Loss: 0.0111
# Epoch [9/10], Val Loss: 0.0112
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch [10/10], Loss: 0.0107
# Epoch [10/10], Val Loss: 0.0108
# Generating predictions...

# %%
args = AttrDict()
args_dict = {
              'gpu':True, 
              'valid':False, 
              'checkpoint':"", 
              'kernel':3,
              'num_filters':32, 
              'learn_rate':0.001, 
              'batch_size':100, 
              'epochs':20, 
              'seed':0,
              'plot':True, 
              'experiment_name': 'regression_cnn',
              'visualize': False,
              'downsize_input':False,
}
args.update(args_dict)
cnn = train(args)
# Out:
# RegressionCNN(
#   (downconv1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (downconv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (rfconv): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (upconv1): Sequential(
#     (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Upsample(scale_factor=2.0, mode=nearest)
#   )
#   (upconv2): Sequential(
#     (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Upsample(scale_factor=2.0, mode=nearest)
#   )
#   (finalconv): MyConv2d()
# )
# Loading data...
# data/cifar-10-batches-py.tar.gz
# Beginning training ...
# Epoch [1/20], Loss: 0.0256
# Epoch [1/20], Val Loss: 0.0271
# Epoch [2/20], Loss: 0.0185
# Epoch [2/20], Val Loss: 0.0188
# Epoch [3/20], Loss: 0.0159
# Epoch [3/20], Val Loss: 0.0162
# Epoch [4/20], Loss: 0.0142
# Epoch [4/20], Val Loss: 0.0144
# Epoch [5/20], Loss: 0.0130
# Epoch [5/20], Val Loss: 0.0132
# Epoch [6/20], Loss: 0.0122
# Epoch [6/20], Val Loss: 0.0123
# Epoch [7/20], Loss: 0.0115
# Epoch [7/20], Val Loss: 0.0116
# Epoch [8/20], Loss: 0.0110
# Epoch [8/20], Val Loss: 0.0111
# Epoch [9/20], Loss: 0.0106
# Epoch [9/20], Val Loss: 0.0107
# Epoch [10/20], Loss: 0.0103
# Epoch [10/20], Val Loss: 0.0102
# Epoch [11/20], Loss: 0.0101
# Epoch [11/20], Val Loss: 0.0099
# Epoch [12/20], Loss: 0.0098
# Epoch [12/20], Val Loss: 0.0096
# Epoch [13/20], Loss: 0.0096
# Epoch [13/20], Val Loss: 0.0094
# Epoch [14/20], Loss: 0.0094
# Epoch [14/20], Val Loss: 0.0092
# Epoch [15/20], Loss: 0.0092
# Epoch [15/20], Val Loss: 0.0091
# Epoch [16/20], Loss: 0.0091
# Epoch [16/20], Val Loss: 0.0089
# Epoch [17/20], Loss: 0.0089
# Epoch [17/20], Val Loss: 0.0088
# Epoch [18/20], Loss: 0.0088
# Epoch [18/20], Val Loss: 0.0087
# Epoch [19/20], Loss: 0.0087
# Epoch [19/20], Val Loss: 0.0086
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch [20/20], Loss: 0.0086
# Epoch [20/20], Val Loss: 0.0084
# Generating predictions...

# %%
args = AttrDict()
args_dict = {
              'gpu':True, 
              'valid':False, 
              'checkpoint':"", 
              'kernel':3,
              'num_filters':32, 
              'learn_rate':0.001, 
              'batch_size':100, 
              'epochs':25, 
              'seed':0,
              'plot':True, 
              'experiment_name': 'regression_cnn',
              'visualize': False,
              'downsize_input':False,
}
args.update(args_dict)
cnn = train(args)
# Out:
# RegressionCNN(
#   (downconv1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (downconv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (rfconv): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (upconv1): Sequential(
#     (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Upsample(scale_factor=2.0, mode=nearest)
#   )
#   (upconv2): Sequential(
#     (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Upsample(scale_factor=2.0, mode=nearest)
#   )
#   (finalconv): MyConv2d()
# )
# Loading data...
# data/cifar-10-batches-py.tar.gz
# Beginning training ...
# Epoch [1/25], Loss: 0.1975
# Epoch [1/25], Val Loss: 0.1816
# Epoch [2/25], Loss: 0.0710
# Epoch [2/25], Val Loss: 0.0646
# Epoch [3/25], Loss: 0.0266
# Epoch [3/25], Val Loss: 0.0244
# Epoch [4/25], Loss: 0.0168
# Epoch [4/25], Val Loss: 0.0166
# Epoch [5/25], Loss: 0.0149
# Epoch [5/25], Val Loss: 0.0149
# Epoch [6/25], Loss: 0.0139
# Epoch [6/25], Val Loss: 0.0139
# Epoch [7/25], Loss: 0.0132
# Epoch [7/25], Val Loss: 0.0131
# Epoch [8/25], Loss: 0.0126
# Epoch [8/25], Val Loss: 0.0126
# Epoch [9/25], Loss: 0.0122
# Epoch [9/25], Val Loss: 0.0121
# Epoch [10/25], Loss: 0.0118
# Epoch [10/25], Val Loss: 0.0117
# Epoch [11/25], Loss: 0.0115
# Epoch [11/25], Val Loss: 0.0114
# Epoch [12/25], Loss: 0.0112
# Epoch [12/25], Val Loss: 0.0111
# Epoch [13/25], Loss: 0.0109
# Epoch [13/25], Val Loss: 0.0108
# Epoch [14/25], Loss: 0.0107
# Epoch [14/25], Val Loss: 0.0106
# Epoch [15/25], Loss: 0.0105
# Epoch [15/25], Val Loss: 0.0103
# Epoch [16/25], Loss: 0.0103
# Epoch [16/25], Val Loss: 0.0101
# Epoch [17/25], Loss: 0.0102
# Epoch [17/25], Val Loss: 0.0099
# Epoch [18/25], Loss: 0.0100
# Epoch [18/25], Val Loss: 0.0098
# Epoch [19/25], Loss: 0.0099
# Epoch [19/25], Val Loss: 0.0096
# Epoch [20/25], Loss: 0.0097
# Epoch [20/25], Val Loss: 0.0095
# Epoch [21/25], Loss: 0.0096
# Epoch [21/25], Val Loss: 0.0094
# Epoch [22/25], Loss: 0.0095
# Epoch [22/25], Val Loss: 0.0092
# Epoch [23/25], Loss: 0.0094
# Epoch [23/25], Val Loss: 0.0091
# Epoch [24/25], Loss: 0.0093
# Epoch [24/25], Val Loss: 0.0090
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch [25/25], Loss: 0.0092
# Epoch [25/25], Val Loss: 0.0090
# Generating predictions...

# %%
args = AttrDict()
args_dict = {
              'gpu':True, 
              'valid':False, 
              'checkpoint':"", 
              'kernel':3,
              'num_filters':32, 
              'learn_rate':0.001, 
              'batch_size':100, 
              'epochs':30, 
              'seed':0,
              'plot':True, 
              'experiment_name': 'regression_cnn',
              'visualize': False,
              'downsize_input':False,
}
args.update(args_dict)
cnn = train(args)
# Out:
# RegressionCNN(
#   (downconv1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (downconv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (rfconv): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (upconv1): Sequential(
#     (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Upsample(scale_factor=2.0, mode=nearest)
#   )
#   (upconv2): Sequential(
#     (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Upsample(scale_factor=2.0, mode=nearest)
#   )
#   (finalconv): MyConv2d()
# )
# Loading data...
# data/cifar-10-batches-py.tar.gz
# Beginning training ...
# Epoch [1/30], Loss: 0.0246
# Epoch [1/30], Val Loss: 0.0296
# Epoch [2/30], Loss: 0.0186
# Epoch [2/30], Val Loss: 0.0188
# Epoch [3/30], Loss: 0.0167
# Epoch [3/30], Val Loss: 0.0168
# Epoch [4/30], Loss: 0.0154
# Epoch [4/30], Val Loss: 0.0154
# Epoch [5/30], Loss: 0.0143
# Epoch [5/30], Val Loss: 0.0143
# Epoch [6/30], Loss: 0.0134
# Epoch [6/30], Val Loss: 0.0135
# Epoch [7/30], Loss: 0.0127
# Epoch [7/30], Val Loss: 0.0127
# Epoch [8/30], Loss: 0.0120
# Epoch [8/30], Val Loss: 0.0121
# Epoch [9/30], Loss: 0.0115
# Epoch [9/30], Val Loss: 0.0116
# Epoch [10/30], Loss: 0.0110
# Epoch [10/30], Val Loss: 0.0111
# Epoch [11/30], Loss: 0.0107
# Epoch [11/30], Val Loss: 0.0106
# Epoch [12/30], Loss: 0.0104
# Epoch [12/30], Val Loss: 0.0103
# Epoch [13/30], Loss: 0.0101
# Epoch [13/30], Val Loss: 0.0100
# Epoch [14/30], Loss: 0.0099
# Epoch [14/30], Val Loss: 0.0097
# Epoch [15/30], Loss: 0.0096
# Epoch [15/30], Val Loss: 0.0095
# Epoch [16/30], Loss: 0.0094
# Epoch [16/30], Val Loss: 0.0093
# Epoch [17/30], Loss: 0.0093
# Epoch [17/30], Val Loss: 0.0091
# Epoch [18/30], Loss: 0.0091
# Epoch [18/30], Val Loss: 0.0090
# Epoch [19/30], Loss: 0.0089
# Epoch [19/30], Val Loss: 0.0089
# Epoch [20/30], Loss: 0.0088
# Epoch [20/30], Val Loss: 0.0087
# Epoch [21/30], Loss: 0.0087
# Epoch [21/30], Val Loss: 0.0086
# Epoch [22/30], Loss: 0.0086
# Epoch [22/30], Val Loss: 0.0086
# Epoch [23/30], Loss: 0.0085
# Epoch [23/30], Val Loss: 0.0085
# Epoch [24/30], Loss: 0.0084
# Epoch [24/30], Val Loss: 0.0084
# Epoch [25/30], Loss: 0.0083
# Epoch [25/30], Val Loss: 0.0083
# Epoch [26/30], Loss: 0.0083
# Epoch [26/30], Val Loss: 0.0082
# Epoch [27/30], Loss: 0.0082
# Epoch [27/30], Val Loss: 0.0082
# Epoch [28/30], Loss: 0.0081
# Epoch [28/30], Val Loss: 0.0081
# Epoch [29/30], Loss: 0.0081
# Epoch [29/30], Val Loss: 0.0081
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch [30/30], Loss: 0.0080
# Epoch [30/30], Val Loss: 0.0080
# Generating predictions...

# %%
args = AttrDict()
args_dict = {
              'gpu':True, 
              'valid':False, 
              'checkpoint':"", 
              'kernel':3,
              'num_filters':32, 
              'learn_rate':0.001, 
              'batch_size':100, 
              'epochs':300, 
              'seed':0,
              'plot':True, 
              'experiment_name': 'regression_cnn',
              'visualize': False,
              'downsize_input':False,
}
args.update(args_dict)
cnn = train(args)
# Out:
# RegressionCNN(
#   (downconv1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (downconv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (rfconv): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (upconv1): Sequential(
#     (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Upsample(scale_factor=2.0, mode=nearest)
#   )
#   (upconv2): Sequential(
#     (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Upsample(scale_factor=2.0, mode=nearest)
#   )
#   (finalconv): MyConv2d()
# )
# Loading data...
# data/cifar-10-batches-py.tar.gz
# Beginning training ...
# Epoch [1/300], Loss: 0.0682
# Epoch [1/300], Val Loss: 0.0826
# Epoch [2/300], Loss: 0.0270
# Epoch [2/300], Val Loss: 0.0259
# Epoch [3/300], Loss: 0.0190
# Epoch [3/300], Val Loss: 0.0184
# Epoch [4/300], Loss: 0.0162
# Epoch [4/300], Val Loss: 0.0155
# Epoch [5/300], Loss: 0.0146
# Epoch [5/300], Val Loss: 0.0142
# Epoch [6/300], Loss: 0.0138
# Epoch [6/300], Val Loss: 0.0134
# Epoch [7/300], Loss: 0.0133
# Epoch [7/300], Val Loss: 0.0128
# Epoch [8/300], Loss: 0.0129
# Epoch [8/300], Val Loss: 0.0126
# Epoch [9/300], Loss: 0.0126
# Epoch [9/300], Val Loss: 0.0124
# Epoch [10/300], Loss: 0.0124
# Epoch [10/300], Val Loss: 0.0119
# Epoch [11/300], Loss: 0.0122
# Epoch [11/300], Val Loss: 0.0115
# Epoch [12/300], Loss: 0.0119
# Epoch [12/300], Val Loss: 0.0113
# Epoch [13/300], Loss: 0.0117
# Epoch [13/300], Val Loss: 0.0111
# Epoch [14/300], Loss: 0.0114
# Epoch [14/300], Val Loss: 0.0109
# Epoch [15/300], Loss: 0.0111
# Epoch [15/300], Val Loss: 0.0107
# Epoch [16/300], Loss: 0.0109
# Epoch [16/300], Val Loss: 0.0105
# Epoch [17/300], Loss: 0.0107
# Epoch [17/300], Val Loss: 0.0103
# Epoch [18/300], Loss: 0.0105
# Epoch [18/300], Val Loss: 0.0102
# Epoch [19/300], Loss: 0.0103
# Epoch [19/300], Val Loss: 0.0100
# Epoch [20/300], Loss: 0.0101
# Epoch [20/300], Val Loss: 0.0098
# Epoch [21/300], Loss: 0.0099
# Epoch [21/300], Val Loss: 0.0097
# Epoch [22/300], Loss: 0.0097
# Epoch [22/300], Val Loss: 0.0096
# Epoch [23/300], Loss: 0.0096
# Epoch [23/300], Val Loss: 0.0094
# Epoch [24/300], Loss: 0.0094
# Epoch [24/300], Val Loss: 0.0093
# Epoch [25/300], Loss: 0.0092
# Epoch [25/300], Val Loss: 0.0092
# Epoch [26/300], Loss: 0.0091
# Epoch [26/300], Val Loss: 0.0090
# Epoch [27/300], Loss: 0.0090
# Epoch [27/300], Val Loss: 0.0089
# Epoch [28/300], Loss: 0.0089
# Epoch [28/300], Val Loss: 0.0088
# Epoch [29/300], Loss: 0.0088
# Epoch [29/300], Val Loss: 0.0087
# Epoch [30/300], Loss: 0.0087
# Epoch [30/300], Val Loss: 0.0086
# Epoch [31/300], Loss: 0.0086
# Epoch [31/300], Val Loss: 0.0085
# Epoch [32/300], Loss: 0.0086
# Epoch [32/300], Val Loss: 0.0084
# Epoch [33/300], Loss: 0.0085
# Epoch [33/300], Val Loss: 0.0083
# Epoch [34/300], Loss: 0.0084
# Epoch [34/300], Val Loss: 0.0083
# Epoch [35/300], Loss: 0.0083
# Epoch [35/300], Val Loss: 0.0082
# Epoch [36/300], Loss: 0.0083
# Epoch [36/300], Val Loss: 0.0081
# Epoch [37/300], Loss: 0.0082
# Epoch [37/300], Val Loss: 0.0081
# Epoch [38/300], Loss: 0.0081
# Epoch [38/300], Val Loss: 0.0080
# Epoch [39/300], Loss: 0.0081
# Epoch [39/300], Val Loss: 0.0080
# Epoch [40/300], Loss: 0.0080
# Epoch [40/300], Val Loss: 0.0079
# Epoch [41/300], Loss: 0.0080
# Epoch [41/300], Val Loss: 0.0078
# Epoch [42/300], Loss: 0.0079
# Epoch [42/300], Val Loss: 0.0078
# Epoch [43/300], Loss: 0.0078
# Epoch [43/300], Val Loss: 0.0077
# Epoch [44/300], Loss: 0.0078
# Epoch [44/300], Val Loss: 0.0076
# Epoch [45/300], Loss: 0.0077
# Epoch [45/300], Val Loss: 0.0076
# Epoch [46/300], Loss: 0.0077
# Epoch [46/300], Val Loss: 0.0075
# Epoch [47/300], Loss: 0.0076
# Epoch [47/300], Val Loss: 0.0075
# Epoch [48/300], Loss: 0.0076
# Epoch [48/300], Val Loss: 0.0074
# Epoch [49/300], Loss: 0.0075
# Epoch [49/300], Val Loss: 0.0073
# Epoch [50/300], Loss: 0.0075
# Epoch [50/300], Val Loss: 0.0073
# Epoch [51/300], Loss: 0.0074
# Epoch [51/300], Val Loss: 0.0073
# Epoch [52/300], Loss: 0.0074
# Epoch [52/300], Val Loss: 0.0072
# Epoch [53/300], Loss: 0.0073
# Epoch [53/300], Val Loss: 0.0072
# Epoch [54/300], Loss: 0.0073
# Epoch [54/300], Val Loss: 0.0071
# Epoch [55/300], Loss: 0.0073
# Epoch [55/300], Val Loss: 0.0071
# Epoch [56/300], Loss: 0.0072
# Epoch [56/300], Val Loss: 0.0071
# Epoch [57/300], Loss: 0.0072
# Epoch [57/300], Val Loss: 0.0070
# Epoch [58/300], Loss: 0.0071
# Epoch [58/300], Val Loss: 0.0070
# Epoch [59/300], Loss: 0.0071
# Epoch [59/300], Val Loss: 0.0070
# Epoch [60/300], Loss: 0.0070
# Epoch [60/300], Val Loss: 0.0069
# Epoch [61/300], Loss: 0.0070
# Epoch [61/300], Val Loss: 0.0069
# Epoch [62/300], Loss: 0.0070
# Epoch [62/300], Val Loss: 0.0069
# Epoch [63/300], Loss: 0.0069
# Epoch [63/300], Val Loss: 0.0068
# Epoch [64/300], Loss: 0.0069
# Epoch [64/300], Val Loss: 0.0068
# Epoch [65/300], Loss: 0.0069
# Epoch [65/300], Val Loss: 0.0068
# Epoch [66/300], Loss: 0.0068
# Epoch [66/300], Val Loss: 0.0068
# Epoch [67/300], Loss: 0.0068
# Epoch [67/300], Val Loss: 0.0067
# Epoch [68/300], Loss: 0.0068
# Epoch [68/300], Val Loss: 0.0067
# Epoch [69/300], Loss: 0.0067
# Epoch [69/300], Val Loss: 0.0067
# Epoch [70/300], Loss: 0.0067
# Epoch [70/300], Val Loss: 0.0066
# Epoch [71/300], Loss: 0.0067
# Epoch [71/300], Val Loss: 0.0066
# Epoch [72/300], Loss: 0.0066
# Epoch [72/300], Val Loss: 0.0066
# Epoch [73/300], Loss: 0.0066
# Epoch [73/300], Val Loss: 0.0066
# Epoch [74/300], Loss: 0.0066
# Epoch [74/300], Val Loss: 0.0066
# Epoch [75/300], Loss: 0.0065
# Epoch [75/300], Val Loss: 0.0065
# Epoch [76/300], Loss: 0.0065
# Epoch [76/300], Val Loss: 0.0065
# Epoch [77/300], Loss: 0.0065
# Epoch [77/300], Val Loss: 0.0065
# Epoch [78/300], Loss: 0.0065
# Epoch [78/300], Val Loss: 0.0065
# Epoch [79/300], Loss: 0.0064
# Epoch [79/300], Val Loss: 0.0064
# Epoch [80/300], Loss: 0.0064
# Epoch [80/300], Val Loss: 0.0064
# Epoch [81/300], Loss: 0.0064
# Epoch [81/300], Val Loss: 0.0064
# Epoch [82/300], Loss: 0.0064
# Epoch [82/300], Val Loss: 0.0064
# Epoch [83/300], Loss: 0.0063
# Epoch [83/300], Val Loss: 0.0064
# Epoch [84/300], Loss: 0.0063
# Epoch [84/300], Val Loss: 0.0064
# Epoch [85/300], Loss: 0.0063
# Epoch [85/300], Val Loss: 0.0063
# Epoch [86/300], Loss: 0.0063
# Epoch [86/300], Val Loss: 0.0063
# Epoch [87/300], Loss: 0.0062
# Epoch [87/300], Val Loss: 0.0063
# Epoch [88/300], Loss: 0.0062
# Epoch [88/300], Val Loss: 0.0063
# Epoch [89/300], Loss: 0.0062
# Epoch [89/300], Val Loss: 0.0063
# Epoch [90/300], Loss: 0.0062
# Epoch [90/300], Val Loss: 0.0063
# Epoch [91/300], Loss: 0.0062
# Epoch [91/300], Val Loss: 0.0063
# Epoch [92/300], Loss: 0.0061
# Epoch [92/300], Val Loss: 0.0062
# Epoch [93/300], Loss: 0.0061
# Epoch [93/300], Val Loss: 0.0062
# Epoch [94/300], Loss: 0.0061
# Epoch [94/300], Val Loss: 0.0062
# Epoch [95/300], Loss: 0.0061
# Epoch [95/300], Val Loss: 0.0062
# Epoch [96/300], Loss: 0.0061
# Epoch [96/300], Val Loss: 0.0062
# Epoch [97/300], Loss: 0.0060
# Epoch [97/300], Val Loss: 0.0062
# Epoch [98/300], Loss: 0.0060
# Epoch [98/300], Val Loss: 0.0062
# Epoch [99/300], Loss: 0.0060
# Epoch [99/300], Val Loss: 0.0062
# Epoch [100/300], Loss: 0.0060
# Epoch [100/300], Val Loss: 0.0062
# Epoch [101/300], Loss: 0.0060
# Epoch [101/300], Val Loss: 0.0062
# Epoch [102/300], Loss: 0.0059
# Epoch [102/300], Val Loss: 0.0062
# Epoch [103/300], Loss: 0.0059
# Epoch [103/300], Val Loss: 0.0062
# Epoch [104/300], Loss: 0.0059
# Epoch [104/300], Val Loss: 0.0061
# Epoch [105/300], Loss: 0.0059
# Epoch [105/300], Val Loss: 0.0061
# Epoch [106/300], Loss: 0.0059
# Epoch [106/300], Val Loss: 0.0061
# Epoch [107/300], Loss: 0.0059
# Epoch [107/300], Val Loss: 0.0061
# Epoch [108/300], Loss: 0.0059
# Epoch [108/300], Val Loss: 0.0061
# Epoch [109/300], Loss: 0.0058
# Epoch [109/300], Val Loss: 0.0061
# Epoch [110/300], Loss: 0.0058
# Epoch [110/300], Val Loss: 0.0061
# Epoch [111/300], Loss: 0.0058
# Epoch [111/300], Val Loss: 0.0061
# Epoch [112/300], Loss: 0.0058
# Epoch [112/300], Val Loss: 0.0061
# Epoch [113/300], Loss: 0.0058
# Epoch [113/300], Val Loss: 0.0061
# Epoch [114/300], Loss: 0.0058
# Epoch [114/300], Val Loss: 0.0061
# Epoch [115/300], Loss: 0.0058
# Epoch [115/300], Val Loss: 0.0061
# Epoch [116/300], Loss: 0.0057
# Epoch [116/300], Val Loss: 0.0061
# Epoch [117/300], Loss: 0.0057
# Epoch [117/300], Val Loss: 0.0061
# Epoch [118/300], Loss: 0.0057
# Epoch [118/300], Val Loss: 0.0061
# Epoch [119/300], Loss: 0.0057
# Epoch [119/300], Val Loss: 0.0061
# Epoch [120/300], Loss: 0.0057
# Epoch [120/300], Val Loss: 0.0061
# Epoch [121/300], Loss: 0.0057
# Epoch [121/300], Val Loss: 0.0061
# Epoch [122/300], Loss: 0.0057
# Epoch [122/300], Val Loss: 0.0061
# Epoch [123/300], Loss: 0.0058
# Epoch [123/300], Val Loss: 0.0060
# Epoch [124/300], Loss: 0.0058
# Epoch [124/300], Val Loss: 0.0061
# Epoch [125/300], Loss: 0.0057
# Epoch [125/300], Val Loss: 0.0061
# Epoch [126/300], Loss: 0.0057
# Epoch [126/300], Val Loss: 0.0060
# Epoch [127/300], Loss: 0.0057
# Epoch [127/300], Val Loss: 0.0060
# Epoch [128/300], Loss: 0.0056
# Epoch [128/300], Val Loss: 0.0060
# Epoch [129/300], Loss: 0.0056
# Epoch [129/300], Val Loss: 0.0060
# Epoch [130/300], Loss: 0.0056
# Epoch [130/300], Val Loss: 0.0060
# Epoch [131/300], Loss: 0.0056
# Epoch [131/300], Val Loss: 0.0060
# Epoch [132/300], Loss: 0.0056
# Epoch [132/300], Val Loss: 0.0060
# Epoch [133/300], Loss: 0.0056
# Epoch [133/300], Val Loss: 0.0060
# Epoch [134/300], Loss: 0.0056
# Epoch [134/300], Val Loss: 0.0060
# Epoch [135/300], Loss: 0.0056
# Epoch [135/300], Val Loss: 0.0059
# Epoch [136/300], Loss: 0.0056
# Epoch [136/300], Val Loss: 0.0059
# Epoch [137/300], Loss: 0.0056
# Epoch [137/300], Val Loss: 0.0058
# Epoch [138/300], Loss: 0.0056
# Epoch [138/300], Val Loss: 0.0059
# Epoch [139/300], Loss: 0.0055
# Epoch [139/300], Val Loss: 0.0060
# Epoch [140/300], Loss: 0.0055
# Epoch [140/300], Val Loss: 0.0061
# Epoch [141/300], Loss: 0.0055
# Epoch [141/300], Val Loss: 0.0061
# Epoch [142/300], Loss: 0.0054
# Epoch [142/300], Val Loss: 0.0061
# Epoch [143/300], Loss: 0.0054
# Epoch [143/300], Val Loss: 0.0060
# Epoch [144/300], Loss: 0.0054
# Epoch [144/300], Val Loss: 0.0060
# Epoch [145/300], Loss: 0.0054
# Epoch [145/300], Val Loss: 0.0062
# Epoch [146/300], Loss: 0.0054
# Epoch [146/300], Val Loss: 0.0065
# Epoch [147/300], Loss: 0.0054
# Epoch [147/300], Val Loss: 0.0064
# Epoch [148/300], Loss: 0.0054
# Epoch [148/300], Val Loss: 0.0064
# Epoch [149/300], Loss: 0.0054
# Epoch [149/300], Val Loss: 0.0064
# Epoch [150/300], Loss: 0.0054
# Epoch [150/300], Val Loss: 0.0065
# Epoch [151/300], Loss: 0.0053
# Epoch [151/300], Val Loss: 0.0065
# Epoch [152/300], Loss: 0.0053
# Epoch [152/300], Val Loss: 0.0065
# Epoch [153/300], Loss: 0.0053
# Epoch [153/300], Val Loss: 0.0063
# Epoch [154/300], Loss: 0.0053
# Epoch [154/300], Val Loss: 0.0062
# Epoch [155/300], Loss: 0.0053
# Epoch [155/300], Val Loss: 0.0062
# Epoch [156/300], Loss: 0.0053
# Epoch [156/300], Val Loss: 0.0062
# Epoch [157/300], Loss: 0.0053
# Epoch [157/300], Val Loss: 0.0062
# Epoch [158/300], Loss: 0.0052
# Epoch [158/300], Val Loss: 0.0063
# Epoch [159/300], Loss: 0.0052
# Epoch [159/300], Val Loss: 0.0063
# Epoch [160/300], Loss: 0.0052
# Epoch [160/300], Val Loss: 0.0063
# Epoch [161/300], Loss: 0.0052
# Epoch [161/300], Val Loss: 0.0062
# Epoch [162/300], Loss: 0.0052
# Epoch [162/300], Val Loss: 0.0060
# Epoch [163/300], Loss: 0.0052
# Epoch [163/300], Val Loss: 0.0059
# Epoch [164/300], Loss: 0.0052
# Epoch [164/300], Val Loss: 0.0059
# Epoch [165/300], Loss: 0.0052
# Epoch [165/300], Val Loss: 0.0059
# Epoch [166/300], Loss: 0.0051
# Epoch [166/300], Val Loss: 0.0059
# Epoch [167/300], Loss: 0.0051
# Epoch [167/300], Val Loss: 0.0059
# Epoch [168/300], Loss: 0.0051
# Epoch [168/300], Val Loss: 0.0059
# Epoch [169/300], Loss: 0.0051
# Epoch [169/300], Val Loss: 0.0059
# Epoch [170/300], Loss: 0.0051
# Epoch [170/300], Val Loss: 0.0059
# Epoch [171/300], Loss: 0.0051
# Epoch [171/300], Val Loss: 0.0059
# Epoch [172/300], Loss: 0.0050
# Epoch [172/300], Val Loss: 0.0059
# Epoch [173/300], Loss: 0.0050
# Epoch [173/300], Val Loss: 0.0059
# Epoch [174/300], Loss: 0.0050
# Epoch [174/300], Val Loss: 0.0059
# Epoch [175/300], Loss: 0.0050
# Epoch [175/300], Val Loss: 0.0059
# Epoch [176/300], Loss: 0.0050
# Epoch [176/300], Val Loss: 0.0059
# Epoch [177/300], Loss: 0.0050
# Epoch [177/300], Val Loss: 0.0059
# Epoch [178/300], Loss: 0.0050
# Epoch [178/300], Val Loss: 0.0059
# Epoch [179/300], Loss: 0.0050
# Epoch [179/300], Val Loss: 0.0060
# Epoch [180/300], Loss: 0.0050
# Epoch [180/300], Val Loss: 0.0060
# Epoch [181/300], Loss: 0.0050
# Epoch [181/300], Val Loss: 0.0060
# Epoch [182/300], Loss: 0.0050
# Epoch [182/300], Val Loss: 0.0060
# Epoch [183/300], Loss: 0.0050
# Epoch [183/300], Val Loss: 0.0060
# Epoch [184/300], Loss: 0.0050
# Epoch [184/300], Val Loss: 0.0060
# Epoch [185/300], Loss: 0.0050
# Epoch [185/300], Val Loss: 0.0060
# Epoch [186/300], Loss: 0.0050
# Epoch [186/300], Val Loss: 0.0060
# Epoch [187/300], Loss: 0.0050
# Epoch [187/300], Val Loss: 0.0060
# Epoch [188/300], Loss: 0.0050
# Epoch [188/300], Val Loss: 0.0060
# Epoch [189/300], Loss: 0.0050
# Epoch [189/300], Val Loss: 0.0060
# Epoch [190/300], Loss: 0.0050
# Epoch [190/300], Val Loss: 0.0060
# Epoch [191/300], Loss: 0.0050
# Epoch [191/300], Val Loss: 0.0061
# Epoch [192/300], Loss: 0.0050
# Epoch [192/300], Val Loss: 0.0062
# Epoch [193/300], Loss: 0.0050
# Epoch [193/300], Val Loss: 0.0060
# Epoch [194/300], Loss: 0.0050
# Epoch [194/300], Val Loss: 0.0060
# Epoch [195/300], Loss: 0.0051
# Epoch [195/300], Val Loss: 0.0080
# Epoch [196/300], Loss: 0.0050
# Epoch [196/300], Val Loss: 0.0069
# Epoch [197/300], Loss: 0.0050
# Epoch [197/300], Val Loss: 0.0067
# Epoch [198/300], Loss: 0.0050
# Epoch [198/300], Val Loss: 0.0071
# Epoch [199/300], Loss: 0.0050
# Epoch [199/300], Val Loss: 0.0073
# Epoch [200/300], Loss: 0.0050
# Epoch [200/300], Val Loss: 0.0072
# Epoch [201/300], Loss: 0.0050
# Epoch [201/300], Val Loss: 0.0069
# Epoch [202/300], Loss: 0.0050
# Epoch [202/300], Val Loss: 0.0070
# Epoch [203/300], Loss: 0.0049
# Epoch [203/300], Val Loss: 0.0068
# Epoch [204/300], Loss: 0.0049
# Epoch [204/300], Val Loss: 0.0067
# Epoch [205/300], Loss: 0.0049
# Epoch [205/300], Val Loss: 0.0065
# Epoch [206/300], Loss: 0.0049
# Epoch [206/300], Val Loss: 0.0065
# Epoch [207/300], Loss: 0.0049
# Epoch [207/300], Val Loss: 0.0067
# Epoch [208/300], Loss: 0.0049
# Epoch [208/300], Val Loss: 0.0069
# Epoch [209/300], Loss: 0.0048
# Epoch [209/300], Val Loss: 0.0068
# Epoch [210/300], Loss: 0.0048
# Epoch [210/300], Val Loss: 0.0068
# Epoch [211/300], Loss: 0.0048
# Epoch [211/300], Val Loss: 0.0068
# Epoch [212/300], Loss: 0.0048
# Epoch [212/300], Val Loss: 0.0067
# Epoch [213/300], Loss: 0.0048
# Epoch [213/300], Val Loss: 0.0069
# Epoch [214/300], Loss: 0.0048
# Epoch [214/300], Val Loss: 0.0068
# Epoch [215/300], Loss: 0.0048
# Epoch [215/300], Val Loss: 0.0069
# Epoch [216/300], Loss: 0.0048
# Epoch [216/300], Val Loss: 0.0068
# Epoch [217/300], Loss: 0.0048
# Epoch [217/300], Val Loss: 0.0069
# Epoch [218/300], Loss: 0.0048
# Epoch [218/300], Val Loss: 0.0067
# Epoch [219/300], Loss: 0.0048
# Epoch [219/300], Val Loss: 0.0067
# Epoch [220/300], Loss: 0.0048
# Epoch [220/300], Val Loss: 0.0067
# Epoch [221/300], Loss: 0.0048
# Epoch [221/300], Val Loss: 0.0068
# Epoch [222/300], Loss: 0.0048
# Epoch [222/300], Val Loss: 0.0068
# Epoch [223/300], Loss: 0.0048
# Epoch [223/300], Val Loss: 0.0066
# Epoch [224/300], Loss: 0.0048
# Epoch [224/300], Val Loss: 0.0066
# Epoch [225/300], Loss: 0.0048
# Epoch [225/300], Val Loss: 0.0066
# Epoch [226/300], Loss: 0.0048
# Epoch [226/300], Val Loss: 0.0066
# Epoch [227/300], Loss: 0.0048
# Epoch [227/300], Val Loss: 0.0065
# Epoch [228/300], Loss: 0.0048
# Epoch [228/300], Val Loss: 0.0066
# Epoch [229/300], Loss: 0.0047
# Epoch [229/300], Val Loss: 0.0066
# Epoch [230/300], Loss: 0.0048
# Epoch [230/300], Val Loss: 0.0065
# Epoch [231/300], Loss: 0.0049
# Epoch [231/300], Val Loss: 0.0075
# Epoch [232/300], Loss: 0.0049
# Epoch [232/300], Val Loss: 0.0092
# Epoch [233/300], Loss: 0.0048
# Epoch [233/300], Val Loss: 0.0091
# Epoch [234/300], Loss: 0.0048
# Epoch [234/300], Val Loss: 0.0088
# Epoch [235/300], Loss: 0.0048
# Epoch [235/300], Val Loss: 0.0087
# Epoch [236/300], Loss: 0.0047
# Epoch [236/300], Val Loss: 0.0081
# Epoch [237/300], Loss: 0.0048
# Epoch [237/300], Val Loss: 0.0082
# Epoch [238/300], Loss: 0.0048
# Epoch [238/300], Val Loss: 0.0079
# Epoch [239/300], Loss: 0.0048
# Epoch [239/300], Val Loss: 0.0078
# Epoch [240/300], Loss: 0.0047
# Epoch [240/300], Val Loss: 0.0076
# Epoch [241/300], Loss: 0.0047
# Epoch [241/300], Val Loss: 0.0076
# Epoch [242/300], Loss: 0.0047
# Epoch [242/300], Val Loss: 0.0072
# Epoch [243/300], Loss: 0.0047
# Epoch [243/300], Val Loss: 0.0072
# Epoch [244/300], Loss: 0.0047
# Epoch [244/300], Val Loss: 0.0070
# Epoch [245/300], Loss: 0.0047
# Epoch [245/300], Val Loss: 0.0071
# Epoch [246/300], Loss: 0.0047
# Epoch [246/300], Val Loss: 0.0071
# Epoch [247/300], Loss: 0.0047
# Epoch [247/300], Val Loss: 0.0073
# Epoch [248/300], Loss: 0.0047
# Epoch [248/300], Val Loss: 0.0071
# Epoch [249/300], Loss: 0.0047
# Epoch [249/300], Val Loss: 0.0070
# Epoch [250/300], Loss: 0.0047
# Epoch [250/300], Val Loss: 0.0075
# Epoch [251/300], Loss: 0.0048
# Epoch [251/300], Val Loss: 0.0072
# Epoch [252/300], Loss: 0.0048
# Epoch [252/300], Val Loss: 0.0077
# Epoch [253/300], Loss: 0.0048
# Epoch [253/300], Val Loss: 0.0063
# Epoch [254/300], Loss: 0.0048
# Epoch [254/300], Val Loss: 0.0067
# Epoch [255/300], Loss: 0.0047
# Epoch [255/300], Val Loss: 0.0070
# Epoch [256/300], Loss: 0.0047
# Epoch [256/300], Val Loss: 0.0070
# Epoch [257/300], Loss: 0.0048
# Epoch [257/300], Val Loss: 0.0069
# Epoch [258/300], Loss: 0.0048
# Epoch [258/300], Val Loss: 0.0064
# Epoch [259/300], Loss: 0.0048
# Epoch [259/300], Val Loss: 0.0065
# Epoch [260/300], Loss: 0.0048
# Epoch [260/300], Val Loss: 0.0065
# Epoch [261/300], Loss: 0.0048
# Epoch [261/300], Val Loss: 0.0066
# Epoch [262/300], Loss: 0.0047
# Epoch [262/300], Val Loss: 0.0067
# Epoch [263/300], Loss: 0.0047
# Epoch [263/300], Val Loss: 0.0069
# Epoch [264/300], Loss: 0.0047
# Epoch [264/300], Val Loss: 0.0068
# Epoch [265/300], Loss: 0.0047
# Epoch [265/300], Val Loss: 0.0069
# Epoch [266/300], Loss: 0.0047
# Epoch [266/300], Val Loss: 0.0068
# Epoch [267/300], Loss: 0.0047
# Epoch [267/300], Val Loss: 0.0068
# Epoch [268/300], Loss: 0.0046
# Epoch [268/300], Val Loss: 0.0064
# Epoch [269/300], Loss: 0.0046
# Epoch [269/300], Val Loss: 0.0065
# Epoch [270/300], Loss: 0.0046
# Epoch [270/300], Val Loss: 0.0066
# Epoch [271/300], Loss: 0.0046
# Epoch [271/300], Val Loss: 0.0069
# Epoch [272/300], Loss: 0.0046
# Epoch [272/300], Val Loss: 0.0069
# Epoch [273/300], Loss: 0.0046
# Epoch [273/300], Val Loss: 0.0070
# Epoch [274/300], Loss: 0.0046
# Epoch [274/300], Val Loss: 0.0072
# Epoch [275/300], Loss: 0.0047
# Epoch [275/300], Val Loss: 0.0064
# Epoch [276/300], Loss: 0.0046
# Epoch [276/300], Val Loss: 0.0063
# Epoch [277/300], Loss: 0.0046
# Epoch [277/300], Val Loss: 0.0065
# Epoch [278/300], Loss: 0.0046
# Epoch [278/300], Val Loss: 0.0065
# Epoch [279/300], Loss: 0.0046
# Epoch [279/300], Val Loss: 0.0067
# Epoch [280/300], Loss: 0.0046
# Epoch [280/300], Val Loss: 0.0066
# Epoch [281/300], Loss: 0.0046
# Epoch [281/300], Val Loss: 0.0065
# Epoch [282/300], Loss: 0.0046
# Epoch [282/300], Val Loss: 0.0066
# Epoch [283/300], Loss: 0.0046
# Epoch [283/300], Val Loss: 0.0065
# Epoch [284/300], Loss: 0.0046
# Epoch [284/300], Val Loss: 0.0064
# Epoch [285/300], Loss: 0.0046
# Epoch [285/300], Val Loss: 0.0065
# Epoch [286/300], Loss: 0.0046
# Epoch [286/300], Val Loss: 0.0063
# Epoch [287/300], Loss: 0.0047
# Epoch [287/300], Val Loss: 0.0062
# Epoch [288/300], Loss: 0.0047
# Epoch [288/300], Val Loss: 0.0061
# Epoch [289/300], Loss: 0.0047
# Epoch [289/300], Val Loss: 0.0061
# Epoch [290/300], Loss: 0.0047
# Epoch [290/300], Val Loss: 0.0062
# Epoch [291/300], Loss: 0.0048
# Epoch [291/300], Val Loss: 0.0063
# Epoch [292/300], Loss: 0.0049
# Epoch [292/300], Val Loss: 0.0066
# Epoch [293/300], Loss: 0.0048
# Epoch [293/300], Val Loss: 0.0061
# Epoch [294/300], Loss: 0.0048
# Epoch [294/300], Val Loss: 0.0059
# Epoch [295/300], Loss: 0.0048
# Epoch [295/300], Val Loss: 0.0059
# Epoch [296/300], Loss: 0.0048
# Epoch [296/300], Val Loss: 0.0060
# Epoch [297/300], Loss: 0.0048
# Epoch [297/300], Val Loss: 0.0060
# Epoch [298/300], Loss: 0.0048
# Epoch [298/300], Val Loss: 0.0060
# Epoch [299/300], Loss: 0.0048
# Epoch [299/300], Val Loss: 0.0060
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch [300/300], Loss: 0.0048
# Epoch [300/300], Val Loss: 0.0063
# Generating predictions...
